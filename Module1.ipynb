# %%
print("Hello World")
# Out:
# Hello World

# %%
a = 2
b = 7
c = 1
print(a+b+c)
# Out:
# 10

# %%
import numpy
import pandas

# %%
# %matplotlib inline
import matplotlib.pylab as plt

# %%
plt.scatter([3,2,5], [1,2,3])
